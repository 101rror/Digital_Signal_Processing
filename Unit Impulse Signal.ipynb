# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.arange(-3, 4, 1)
y = np.concatenate((np.zeros(3), [1], np.zeros(3)))

# %%
plt.stem(t, y)
plt.xlabel('a(n)------->')
plt.ylabel('Amplitude-------->')
plt.title('Unit Impulse Signal')
plt.show()
