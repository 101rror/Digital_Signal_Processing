# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.arange(0, np.pi, 0.05)
y = np.sin(2 * np.pi * t)

# %%
plt.stem(t, y)
plt.xlabel('(d)n------->')
plt.ylabel('Amplitude-------->')
plt.title(' Sine sequence')
plt.show()
